# %%
import numpy as np
import cvxpy as cp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def optimize_accel(matrix):
    m, n = matrix.shape
    # 最適化変数
    B = cp.Variable((m, n))
    # 目的関数: 元データとの差を最小化
    objective = cp.Minimize(cp.sum_squares(B - matrix))
    # 制約: 行・列の単調性を強制
    constraints = []
    for i in range(m):
        for j in range(n - 1):
            constraints.append(B[i, j + 1] <= B[i, j])  # 行方向
    for i in range(m - 1):
        for j in range(n):
            constraints.append(B[i, j] <= B[i + 1, j])  # 列方向
    # 問題を定義
    problem = cp.Problem(objective, constraints)
    problem.solve()
    return B.value

# %%
def optimize_brake(matrix):
    m, n = matrix.shape
    # 最適化変数
    B = cp.Variable((m, n))
    # 目的関数: 元データとの差を最小化
    objective = cp.Minimize(cp.sum_squares(B - matrix))
    # 制約: 行・列の単調性を強制
    constraints = []
    for i in range(m):
        for j in range(n - 1):
            constraints.append(B[i, j+ 1] <= B[i, j])  # 行方向
    for i in range(m - 1):
        for j in range(n):
            constraints.append(B[i+1, j] <= B[i, j])  # 列方向
    # 問題を定義
    problem = cp.Problem(objective, constraints)
    problem.solve()
    return B.value

# %%
def compute_row_neighbors_average(matrix):
    rows, cols = matrix.shape
    result = np.zeros_like(matrix, dtype=float)  # 結果用の行列を作成

    for i in range(rows):
        for j in range(cols):
            # 近傍要素のリスト
            if abs(matrix[i,j]) < 1e-6:
                neighbors = []
                # 上
                #if i > 0 and abs(matrix[i-1, j]) > 1e-6:
                    #neighbors.append(matrix[i-1, j])
                # 下
                #if i < rows-1 and abs(matrix[i+1, j]) > 1e-6:
                    #neighbors.append(matrix[i+1, j])
                # 左
                if j > 0 and abs(matrix[i, j-1]) > 1e-6:
                    neighbors.append(matrix[i, j-1])
                # 右
                if j < cols-1 and abs(matrix[i, j+1]) > 1e-6:
                    neighbors.append(matrix[i, j+1])
                
                # 平均を計算（近傍が存在する場合のみ）
                if neighbors:
                    matrix[i, j] = sum(neighbors) / len(neighbors)
                else:
                    matrix[i, j] = 0.0  # 近傍がない場合は 0.0 にする（任意の値に調整可能

    return matrix

def compute_col_neighbors_average(matrix):
    rows, cols = matrix.shape
    result = np.zeros_like(matrix, dtype=float)  # 結果用の行列を作成

    for i in range(rows):
        for j in range(cols):
            # 近傍要素のリスト
            if abs(matrix[i,j]) < 1e-6:
                neighbors = []
                # 上
                if i > 0 and abs(matrix[i-1, j]) > 1e-6:
                    neighbors.append(matrix[i-1, j])
                # 下
                if i < rows-1 and abs(matrix[i+1, j]) > 1e-6:
                    neighbors.append(matrix[i+1, j])
                
                # 平均を計算（近傍が存在する場合のみ）
                if neighbors:
                    matrix[i, j] = sum(neighbors) / len(neighbors)
                else:
                    matrix[i, j] = 0.0  # 近傍がない場合は 0.0 にする（任意の値に調整可能）7
    return matrix

# %%
import pandas as pd
accel_map_ = pd.read_csv("accel_map.csv", delimiter=",", header=0)
accel_map = accel_map_.to_numpy()[:,1:]
accel_map

brake_map_ = pd.read_csv("brake_map.csv", delimiter=",", header=0)
brake_map = brake_map_.to_numpy()[:,1:]

# %%
accel_map
# Out:
# array([[ 0.232, -0.127, -0.246, -0.311, -0.312, -0.35 , -0.351, -0.359,
#         -0.36 , -0.363, -0.456],
#        [ 0.745,  0.384,  0.294,  0.045,  0.03 ,  0.029, -0.157, -0.186,
#         -0.187, -0.188, -0.251],
#        [ 1.113,  0.785,  0.765,  0.647,  0.603,  0.423,  0.264,  0.059,
#          0.047,  0.04 ,  0.038],
#        [ 1.56 ,  1.423,  1.242,  1.241,  1.24 ,  1.117,  0.784,  0.443,
#          0.305,  0.292,  0.291],
#        [ 2.18 ,  1.91 ,  1.681,  1.581,  1.499,  1.155,  0.965,  0.806,
#          0.805,  0.804,  0.803],
#        [ 3.03 ,  2.76 ,  2.57 ,  2.44 ,  2.35 ,  2.3  ,  2.26 ,  2.22 ,
#          2.16 ,  2.07 ,  1.94 ]])

# %%
brake_map
# Out:
# array([[ 0.232, -0.127, -0.246, -0.331, -0.332, -0.373, -0.374, -0.376,
#         -0.377, -0.378, -0.456],
#        [ 0.186, -0.131, -0.247, -0.348, -0.371, -0.384, -0.392, -0.496,
#         -0.604, -0.691, -0.836],
#        [-0.524, -0.525, -0.762, -0.853, -0.859, -0.86 , -0.861, -0.921,
#         -1.28 , -1.4  , -1.53 ],
#        [-0.878, -1.133, -1.311, -1.311, -1.312, -1.313, -1.398, -1.45 ,
#         -1.5  , -1.6  , -1.73 ],
#        [-0.94 , -1.478, -1.695, -1.759, -1.95 , -2.01 , -2.04 , -2.08 ,
#         -2.14 , -2.22 , -2.33 ],
#        [-1.48 , -1.74 , -2.36 , -2.361, -2.45 , -2.55 , -2.6  , -2.65 ,
#         -2.75 , -2.86 , -2.94 ],
#        [-2.43 , -2.7  , -3.34 , -3.56 , -3.65 , -3.7  , -3.73 , -3.78 ,
#         -3.81 , -3.811, -3.92 ],
#        [-3.69 , -3.95 , -4.14 , -4.16 , -4.33 , -4.41 , -4.46 , -4.5  ,
#         -4.55 , -4.64 , -4.77 ],
#        [-4.89 , -5.12 , -5.33 , -5.41 , -5.96 , -6.01 , -6.11 , -6.16 ,
#         -6.2  , -6.3  , -6.4  ]])

# %%
accel_m, accel_n = accel_map.shape
brake_m, brake_n = brake_map.shape

map_ = np.zeros((accel_m + brake_m - 1, accel_n))

map_[:accel_m, :] = accel_map[::-1,:]
for i in range(accel_n):
    component = []
    if abs(accel_map[0,i]) > 1e-6:
        component.append(accel_map[0,i])
    if abs(brake_map[0,i]) > 1e-6:
        component.append(brake_map[0,i])
    if component:
        map_[accel_m-1, i] = np.mean(component)
map_[accel_m:,:] = brake_map[1:,:]

# %%
for i in range(len(map_[0,:])):
    map_ = compute_row_neighbors_average(map_)
for j in range(len(brake_map)):
    map_ = compute_col_neighbors_average(map_)
map_ = optimize_brake(map_)
map_
# Out:
# array([[ 3.03  ,  2.76  ,  2.57  ,  2.44  ,  2.35  ,  2.3   ,  2.26  ,
#          2.22  ,  2.16  ,  2.07  ,  1.94  ],
#        [ 2.18  ,  1.91  ,  1.681 ,  1.581 ,  1.499 ,  1.155 ,  0.965 ,
#          0.806 ,  0.805 ,  0.804 ,  0.803 ],
#        [ 1.56  ,  1.423 ,  1.242 ,  1.241 ,  1.24  ,  1.117 ,  0.784 ,
#          0.443 ,  0.305 ,  0.292 ,  0.291 ],
#        [ 1.113 ,  0.785 ,  0.765 ,  0.647 ,  0.603 ,  0.423 ,  0.264 ,
#          0.059 ,  0.047 ,  0.04  ,  0.038 ],
#        [ 0.745 ,  0.384 ,  0.294 ,  0.045 ,  0.03  ,  0.029 , -0.157 ,
#         -0.186 , -0.187 , -0.188 , -0.251 ],
#        [ 0.232 , -0.127 , -0.246 , -0.321 , -0.322 , -0.3615, -0.3625,
#         -0.3675, -0.3685, -0.3705, -0.456 ],
#        [ 0.186 , -0.131 , -0.247 , -0.348 , -0.371 , -0.384 , -0.392 ,
#         -0.496 , -0.604 , -0.691 , -0.836 ],
#        [-0.524 , -0.525 , -0.762 , -0.853 , -0.859 , -0.86  , -0.861 ,
#         -0.921 , -1.28  , -1.4   , -1.53  ],
#        [-0.878 , -1.133 , -1.311 , -1.311 , -1.312 , -1.313 , -1.398 ,
#         -1.45  , -1.5   , -1.6   , -1.73  ],
#        [-0.94  , -1.478 , -1.695 , -1.759 , -1.95  , -2.01  , -2.04  ,
#         -2.08  , -2.14  , -2.22  , -2.33  ],
#        [-1.48  , -1.74  , -2.36  , -2.361 , -2.45  , -2.55  , -2.6   ,
#         -2.65  , -2.75  , -2.86  , -2.94  ],
#        [-2.43  , -2.7   , -3.34  , -3.56  , -3.65  , -3.7   , -3.73  ,
#         -3.78  , -3.81  , -3.811 , -3.92  ],
#        [-3.69  , -3.95  , -4.14  , -4.16  , -4.33  , -4.41  , -4.46  ,
#         -4.5   , -4.55  , -4.64  , -4.77  ],
#        [-4.89  , -5.12  , -5.33  , -5.41  , -5.96  , -6.01  , -6.11  ,
#         -6.16  , -6.2   , -6.3   , -6.4   ]])

# %%
modified_accel_map = map_[:accel_m, :]

# %%
accel_map
# Out:
# array([[ 0.232, -0.127, -0.246, -0.311, -0.312, -0.35 , -0.351, -0.359,
#         -0.36 , -0.363, -0.456],
#        [ 0.745,  0.384,  0.294,  0.045,  0.03 ,  0.029, -0.157, -0.186,
#         -0.187, -0.188, -0.251],
#        [ 1.113,  0.785,  0.765,  0.647,  0.603,  0.423,  0.264,  0.059,
#          0.047,  0.04 ,  0.038],
#        [ 1.56 ,  1.423,  1.242,  1.241,  1.24 ,  1.117,  0.784,  0.443,
#          0.305,  0.292,  0.291],
#        [ 2.18 ,  1.91 ,  1.681,  1.581,  1.499,  1.155,  0.965,  0.806,
#          0.805,  0.804,  0.803],
#        [ 3.03 ,  2.76 ,  2.57 ,  2.44 ,  2.35 ,  2.3  ,  2.26 ,  2.22 ,
#          2.16 ,  2.07 ,  1.94 ]])

# %%
modified_accel_map[::-1,:]
# Out:
# array([[ 0.232 , -0.127 , -0.246 , -0.321 , -0.322 , -0.3615, -0.3625,
#         -0.3675, -0.3685, -0.3705, -0.456 ],
#        [ 0.745 ,  0.384 ,  0.294 ,  0.045 ,  0.03  ,  0.029 , -0.157 ,
#         -0.186 , -0.187 , -0.188 , -0.251 ],
#        [ 1.113 ,  0.785 ,  0.765 ,  0.647 ,  0.603 ,  0.423 ,  0.264 ,
#          0.059 ,  0.047 ,  0.04  ,  0.038 ],
#        [ 1.56  ,  1.423 ,  1.242 ,  1.241 ,  1.24  ,  1.117 ,  0.784 ,
#          0.443 ,  0.305 ,  0.292 ,  0.291 ],
#        [ 2.18  ,  1.91  ,  1.681 ,  1.581 ,  1.499 ,  1.155 ,  0.965 ,
#          0.806 ,  0.805 ,  0.804 ,  0.803 ],
#        [ 3.03  ,  2.76  ,  2.57  ,  2.44  ,  2.35  ,  2.3   ,  2.26  ,
#          2.22  ,  2.16  ,  2.07  ,  1.94  ]])

# %%
modified_brake_map = map_[accel_m-1:, :]

# %%
modified_brake_map
# Out:
# array([[ 0.232 , -0.127 , -0.246 , -0.321 , -0.322 , -0.3615, -0.3625,
#         -0.3675, -0.3685, -0.3705, -0.456 ],
#        [ 0.186 , -0.131 , -0.247 , -0.348 , -0.371 , -0.384 , -0.392 ,
#         -0.496 , -0.604 , -0.691 , -0.836 ],
#        [-0.524 , -0.525 , -0.762 , -0.853 , -0.859 , -0.86  , -0.861 ,
#         -0.921 , -1.28  , -1.4   , -1.53  ],
#        [-0.878 , -1.133 , -1.311 , -1.311 , -1.312 , -1.313 , -1.398 ,
#         -1.45  , -1.5   , -1.6   , -1.73  ],
#        [-0.94  , -1.478 , -1.695 , -1.759 , -1.95  , -2.01  , -2.04  ,
#         -2.08  , -2.14  , -2.22  , -2.33  ],
#        [-1.48  , -1.74  , -2.36  , -2.361 , -2.45  , -2.55  , -2.6   ,
#         -2.65  , -2.75  , -2.86  , -2.94  ],
#        [-2.43  , -2.7   , -3.34  , -3.56  , -3.65  , -3.7   , -3.73  ,
#         -3.78  , -3.81  , -3.811 , -3.92  ],
#        [-3.69  , -3.95  , -4.14  , -4.16  , -4.33  , -4.41  , -4.46  ,
#         -4.5   , -4.55  , -4.64  , -4.77  ],
#        [-4.89  , -5.12  , -5.33  , -5.41  , -5.96  , -6.01  , -6.11  ,
#         -6.16  , -6.2   , -6.3   , -6.4   ]])

# %%
for i in range(len(accel_map)):
    plt.plot( [np.round(i*1.39,2) for i in range(accel_n)] ,accel_map[i,:], label="accel actuation = " + str(np.round(i*0.1, 1)))
plt.title("")
plt.ylabel("acceleration [m/s^2]")
plt.xlabel("velocity [m/s]")
plt.title("Acceleration vs Velocity when constant actuation \n (Before Modification)")
plt.legend()
plt.savefig("Acceleration vs Velocity when constant actuation \n (Before Modification)", bbox_inches='tight')
plt.show()

# %%
for i in range(len(accel_map)):
    plt.plot( [np.round(i*1.39,2) for i in range(accel_n)] ,modified_accel_map[len(accel_map)-1-i,:], label="accel actuation = " + str(np.round(i*0.1, 1)))
plt.title("")
plt.ylabel("acceleration [m/s^2]")
plt.xlabel("velocity [m/s]")
plt.title("Acceleration vs Velocity when constant actuation \n (After Modification)")
plt.legend()
plt.savefig("modified_accel_map.png", bbox_inches='tight')
plt.show()

# %%
np.savetxt("modified_accel_map.csv", modified_accel_map[::-1,:],delimiter=",")

# %%
for i in range(len(brake_map)):
    plt.plot( [np.round(i*1.39,2) for i in range(accel_n)] , brake_map[i,:], label="brake actuation = " + str(np.round(i*0.1, 1)))
plt.title("")
plt.ylabel("acceleration [m/s^2]")
plt.xlabel("velocity [m/s]")
plt.title("Acceleration vs Velocity when constant brake actuation \n (Before Modification)")
plt.legend()
plt.savefig("brake_map.png", bbox_inches='tight')
plt.show()

# %%
for i in range(len(brake_map)):
    plt.plot( [np.round(i*1.39,2) for i in range(accel_n)] ,modified_brake_map[i,:], label="brake actuation = " + str(np.round(i*0.1, 1)))
plt.title("")
plt.ylabel("acceleration [m/s^2]")
plt.xlabel("velocity [m/s]")
plt.title("Acceleration vs Velocity when constant actuation \n (After Modification)")
plt.legend()
plt.savefig("Acceleration vs Velocity when constant actuation \n (After Modification).png", bbox_inches='tight')
plt.show()

# %%
np.savetxt("modified_brake_map.csv", modified_brake_map,delimiter=",")
